# %% [markdown]
# # Airline Mining Project
# -- The goal of this project is to examine airline tweets and data to identify topics they are talking about and the emotions associated with the tweets

# %%
import pandas as pd
import numpy as np
import pickle
import nltk 
import seaborn as sns
import matplotlib.pyplot as plt
import neattext as nfx
import nltk
from nltk.corpus import stopwords
plt.style.use('ggplot')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Julian
# [nltk_data]     Sotelo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Part 1: For all major airlines, generate the word cloud
# -- Southwest, Virgin America, United, Delta, US Airways, American

# %%
from wordcloud import WordCloud
df = pd.read_csv('Tweets.csv')

# %%
df.head(5)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df['text'] = df['text'].apply(nfx.remove_stopwords)
df['text'] = df['text'].apply(nfx.remove_userhandles)
df['text'] = df['text'].apply(nfx.remove_punctuations)
df['text'] = df['text'].apply(nfx.remove_emojis)
df['text'] = df['text'].apply(nfx.remove_hashtags)
df['text'] = df['text'].str.lower()
df['text']
# Out:
# 0                                                     said
# 1                  plus added commercials experience tacky
# 2                                     today mean need trip
# 3          aggressive blast obnoxious entertainment gue...
# 4                                            big bad thing
#                                ...
# 14635                   thank got different flight chicago
# 14636      leaving 20 minutes late flight warnings comm...
# 14637                            bring american airlines
# 14638      money change flight answer phones suggestion...
# 14639      8 ppl need 2 know seats flight plz standby 4...
# Name: text, Length: 14640, dtype: object

# %%
United = df.loc[df.airline == 'United']
Delta = df.loc[df.airline == 'Delta']
Southwest = df.loc[df.airline == 'Southwest']
VirginAmerica = df.loc[df.airline == 'Virgin America']
USAirways = df.loc[df.airline == 'US Airways']
American = df.loc[df.airline ==  'American']


Delta = Delta[['airline', 'text', 'airline_sentiment']]
United = United[['airline', 'text', 'airline_sentiment']]
Southwest = Southwest[['airline', 'text', 'airline_sentiment']]
VirginAmerica = VirginAmerica[['airline', 'text', 'airline_sentiment']]
USAirways = USAirways[['airline', 'text', 'airline_sentiment']]
American = American[['airline', 'text', 'airline_sentiment']]

# %%
Delta_wc = Delta.loc[Delta['airline_sentiment'] == 'positive']
Delta2_wc = Delta.loc[Delta['airline_sentiment'] == 'negative']
Delta3_wc = Delta.loc[Delta['airline_sentiment'] == 'neutral']

United_wc = United.loc[United['airline_sentiment'] == 'positive']
United2_wc = United.loc[United['airline_sentiment'] == 'negative']
United3_wc = United.loc[United['airline_sentiment'] == 'neutral']

# %%
'''
generate_wordcloud(Delta_wc, 'Delta') #Pos
generate_wordcloud(Delta2_wc, 'Delta') # Neut
generate_wordcloud(Delta3_wc, 'Delta') # Neg
'''
# Out:
# "\ngenerate_wordcloud(Delta_wc, 'Delta') #Pos\ngenerate_wordcloud(Delta2_wc, 'Delta') # Neut\ngenerate_wordcloud(Delta3_wc, 'Delta') # Neg\n"

# %%
'''
generate_wordcloud(United_wc, 'United') # Pos
generate_wordcloud(United_wc, 'United') # Neu
generate_wordcloud(United_wc, 'United') # Neg
'''
# Out:
# "\ngenerate_wordcloud(United_wc, 'United') # Pos\ngenerate_wordcloud(United_wc, 'United') # Neu\ngenerate_wordcloud(United_wc, 'United') # Neg\n"

# %%
United_wc = United.loc[United['airline_sentiment'] == 'positive']

# %%
def generate_wordcloud(df, airline):
    text = " ".join(review for review in df["text"])
    wordcloud = WordCloud(width=800, height=800, min_font_size=10).generate(text)

    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)

    plt.title(f"{airline} Word Cloud", fontsize=20)

    plt.show()

# Add flight, thank, other stop words
generate_wordcloud(United, "United")
generate_wordcloud(Delta, "Delta")
generate_wordcloud(Delta, "Southwest")
generate_wordcloud(Delta, "Virgin America")
generate_wordcloud(Delta, "US Airways")
generate_wordcloud(Delta, "American")

# %% [markdown]
# ## Part 2 Show the Distribution of positive/neutral/negative sentiment across all airlines

# %%
airlines = ['United', 'Delta', 'Southwest', 'VirginAmerica', 'USAirways', 'American']

American['airline_sentiment'].value_counts().plot(kind='bar', title=f'Sentiment for American',
                                                figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Sentiment for American'}>

# %%
VirginAmerica['airline_sentiment'].value_counts().plot(kind='bar', title=f'Sentiment for Virgin America',
                                                figsize=(10, 5))
plt.show()

# %%
USAirways['airline_sentiment'].value_counts().plot(kind='bar', title=f'Sentiment for US Airways',
                                                figsize=(10, 5))
plt.show()

# %%
United['airline_sentiment'].value_counts().plot(kind='bar', title=f'Sentiment for United',
                                                figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Sentiment for United'}>

# %%
Delta['airline_sentiment'].value_counts().plot(kind='bar', title=f'Sentiment for Delta',
                                                figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Sentiment for Delta'}>

# %%
Southwest['airline_sentiment'].value_counts().plot(kind='bar', title=f'Sentiment for Southwest',
                                                figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Sentiment for Southwest'}>

# %%
#sns.countplot(df = df, x = 'airline', hue='airline_sentiment')

# %% [markdown]
# ## Part 3: Use the emotion classifier build in HW2 to classify the emotions in these tweets. How are they correlated with the sentiments in Part 2?
# -- Classify Emotions in these tweets using Elbow method, Logistic Regression, and Roberta pretrained model

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# make a copy 
df1 = df

# %%
# Define target and variables
target = df1['airline_sentiment']
text = df1['text']

# %%
# Vectorize and Transform
tf = TfidfVectorizer()
text = tf.fit_transform(text)

# %%
# Split the Data
X_train, X_test, y_train, y_test = train_test_split(text, target, test_size = .2, stratify=target)

# %%
# Naive Bayes 
nv = MultinomialNB()
nv.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nv.score(X_test, y_test)
# Out:
# 0.6909153005464481

# %%
## Make a single Prediction 
sample_text = ['I Love You']

vect = tf.transform(sample_text)

nv.predict(vect)
# Out:
# array(['positive'], dtype='<U8')

# %%
# Logistic Regression
lr = LogisticRegression(max_iter = 5000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
lr.score(X_test, y_test)
# Out:
# 0.7721994535519126

# %%
## Make a single Prediction 
sample_text = ['Why is he acting like a child?!']

vect = tf.transform(sample_text)

lr.predict(vect)
# Out:
# array(['negative'], dtype=object)

# %%
## Try with transformers instead of Vectorizor
from sentence_transformers import SentenceTransformer
df2 = df
df2.reset_index(inplace=True, drop=False)
df2.rename(columns={'index': 'ID'}, inplace=True)
target = df2['airline_sentiment']
text = df2['text']

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
embeddings = model.encode(text)

# %%
X_train, X_test, y_train, y_test = train_test_split(embeddings, target, test_size = .2, stratify=target)

# %%
# Logistic Regression
lr = LogisticRegression(max_iter = 5000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
lr.score(X_test, y_test)
# Out:
# 0.7769808743169399

# %%
## Try Using Roberta PreTrained Sentiment Analyzer and Compare
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
from tqdm.notebook import tqdm
from scipy.special import softmax

MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
example = 'This oatmeal tastes like shit'

encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg': scores[0],
    'roberta_neu': scores[1],
    'roberta_pos': scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.97779834, 'roberta_neu': 0.018760141, 'roberta_pos': 0.003441523}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors = 'pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
    'roberta_neg': scores[0],
    'roberta_neu': scores[1],
    'roberta_pos': scores[2]
    }
    return scores_dict

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
res = {}
for i, row in tqdm(df2.iterrows(), total=len(df2)):
    try:
        text = row['text']
        myid = row['ID']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/14640 [00:00<?, ?it/s]

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'ID'})
results_df = results_df.merge(df2, how='left')

# %%
results_df.columns

# %%
results_df = results_df[['ID', 'airline', 'neg', 'neu', 'pos', 'compound', 'roberta_neg', 'roberta_neu', 'roberta_pos', 'airline_sentiment', 'text']]

# %%
sns.pairplot(data=results_df, vars=['neg', 'neu', 'pos', 'roberta_neg', 'roberta_neu', 'roberta_pos'], 
             hue = 'airline_sentiment', palette = 'tab10')
plt.show()

# %%
results_df

# %% [markdown]
# ## Part 3 Classify Emotion Using HW2

# %% [markdown]
# ## The pickle file achieved a 82% correct rate

# %%
results_df['text']

# %%
# Load Saved Model 
with open('nb_tfidf.pkl', 'rb') as f:
    tfidf, mnb = pickle.load(f)
new_text = results_df['text']
X_new = tfidf.transform(new_text)

y_pred = mnb.predict(X_new)

# %%
results_df['emotion_classif'] = y_pred

# %%
results_df

# %%
## Show Correlation 
pivot_df = pd.pivot_table(results_df, values='compound', index = 'airline', columns = 'emotion_classif', aggfunc='mean')

# %%
results_df

# %%
# Create a heat map to visualize the data
sns.heatmap(pivot_df, cmap='RdYlGn', annot=True, fmt='.1f')

# %%
# save the df 
results_df.to_csv('airlines_tweets.csv', index = False)

# %%
results_df = pd.read_csv('airlines_tweets.csv')

# %%
#!pip install --upgrade gensim
#!pip install pyldavis
import gensim
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from gensim.models import CoherenceModel
from gensim.parsing.preprocessing import preprocess_string

# %%
results_df.head()
# Out:
#    ID         airline    neg    neu    pos  compound  roberta_neg  \
# 0   0  Virgin America  0.000  1.000  0.000    0.0000     0.215634
# 1   1  Virgin America  0.000  1.000  0.000    0.0000     0.497370
# 2   2  Virgin America  0.000  1.000  0.000    0.0000     0.176005
# 3   3  Virgin America  0.343  0.448  0.209   -0.2023     0.556878
# 4   4  Virgin America  0.636  0.364  0.000   -0.5423     0.784228
#
#    roberta_neu  roberta_pos airline_sentiment  \
# 0     0.643773     0.140594           neutral
# 1     0.434796     0.067834          positive
# 2     0.726519     0.097477           neutral
# 3     0.402157     0.040965          negative
# 4     0.187802     0.027970          negative
#
#                                                 text emotion_classif
# 0                                               said        surprise
# 1            plus added commercials experience tacky        surprise
# 2                               today mean need trip      enthusiasm
# 3    aggressive blast obnoxious entertainment gue...       happiness
# 4                                      big bad thing            hate

# %%
results_df
# Out:
#           ID         airline    neg    neu    pos  compound  roberta_neg  \
# 0          0  Virgin America  0.000  1.000  0.000    0.0000     0.215634
# 1          1  Virgin America  0.000  1.000  0.000    0.0000     0.497370
# 2          2  Virgin America  0.000  1.000  0.000    0.0000     0.176005
# 3          3  Virgin America  0.343  0.448  0.209   -0.2023     0.556878
# 4          4  Virgin America  0.636  0.364  0.000   -0.5423     0.784228
# ...      ...             ...    ...    ...    ...       ...          ...
# 14635  14635        American  0.000  0.615  0.385    0.3612     0.088788
# 14636  14636        American  0.293  0.707  0.000   -0.7003     0.870435
# 14637  14637        American  0.000  1.000  0.000    0.0000     0.148454
# 14638  14638        American  0.000  0.698  0.302    0.3818     0.154424
# 14639  14639        American  0.000  0.860  0.140    0.0772     0.216572
#
#        roberta_neu  roberta_pos airline_sentiment  \
# 0         0.643773     0.140594           neutral
# 1         0.434796     0.067834          positive
# 2         0.726519     0.097477           neutral
# 3         0.402157     0.040965          negative
# 4         0.187802     0.027970          negative
# ...            ...          ...               ...
# 14635     0.742508     0.168704          positive
# 14636     0.119604     0.009961          negative
# 14637     0.732113     0.119432           neutral
# 14638     0.786269     0.059307          negative
# 14639     0.738961     0.044468           neutral
#
#                                                     text emotion_classif
# 0                                                   said        surprise
# 1                plus added commercials experience tacky        surprise
# 2                                   today mean need trip      enthusiasm
# 3        aggressive blast obnoxious entertainment gue...       happiness
# 4                                          big bad thing            hate
# ...                                                  ...             ...
# 14635                 thank got different flight chicago          relief
# 14636    leaving 20 minutes late flight warnings comm...            hate
# 14637                          bring american airlines              hate
# 14638    money change flight answer phones suggestion...         neutral
# 14639    8 ppl need 2 know seats flight plz standby 4...      enthusiasm
#
# [14640 rows x 12 columns]

# %%
##1 Flight cancelations
##2 Customer Service - 
##3 Staff and waiting experience
##4 Customer servie 
##5 Website experience
##6 Online flight purchases

# %% [markdown]
# ## Part 4: What topics are people talking about in their tweets? How does this distribution of topics differ across airlines?

# %%
#clean text, wouldnt let me run without this, before the text was just one string
#could possible split it into just strings instead of procescing text not sure best way to go
#about this still thinking for now lol
def preprocess_text(text):
    return preprocess_string(text)

results_df['cleaned_text'] = results_df['text'].apply(preprocess_text)

# %%
#need to create our dictionary and bow corpus to prepare model for LDA
texts = results_df['cleaned_text']
dic = corpora.Dictionary(texts)
corpus = [dic.doc2bow(doc) for doc in results_df['cleaned_text']]

# %%
## find optimal # of topics
## Takes awhile to run
coherence_scores = []
num_topics_range = range(2, 10)  # Check for number of topics from 2 to 20

for num_topics in num_topics_range:
    lda_model = LdaModel(corpus=corpus, id2word=dic, num_topics=num_topics, passes=10, alpha='auto', per_word_topics=True, random_state=42)
    coherence_model = CoherenceModel(model=lda_model, texts=texts, dictionary=dic, coherence='c_v')
    coherence_scores.append(coherence_model.get_coherence())

# Plot coherence scores
plt.plot(num_topics_range, coherence_scores)
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score')
plt.title('Coherence Scores vs. Number of Topics')
plt.show()

# Find the optimal number of topics
optimal_num_topics = num_topics_range[coherence_scores.index(max(coherence_scores))]
print(f"Optimal number of topics: {optimal_num_topics}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 6>()
#       4 num_topics_range = range(2, 10)  # Check for number of topics from 2 to 20
#       6 for num_topics in num_topics_range:
# ----> 7     lda_model = LdaModel(corpus=corpus, id2word=dic, num_topics=num_topics, passes=10, alpha='auto', per_word_topics=True, random_state=42)
#       8     coherence_model = CoherenceModel(model=lda_model, texts=texts, dictionary=dic, coherence='c_v')
#       9     coherence_scores.append(coherence_model.get_coherence())
#
# File ~\anaconda3\lib\site-packages\gensim\models\ldamodel.py:521, in LdaModel.__init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     519 use_numpy = self.dispatcher is not None
#     520 start = time.time()
# --> 521 self.update(corpus, chunks_as_numpy=use_numpy)
#     522 self.add_lifecycle_event(
#     523     "created",
#     524     msg=f"trained {self} in {time.time() - start:.2f}s",
#     525 )
#
# File ~\anaconda3\lib\site-packages\gensim\models\ldamodel.py:1006, in LdaModel.update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#    1001 else:
#    1002     logger.info(
#    1003         "PROGRESS: pass %i, at document #%i/%i",
#    1004         pass_, chunk_no * chunksize + len(chunk), lencorpus
#    1005     )
# -> 1006     gammat = self.do_estep(chunk, other)
#    1008     if self.optimize_alpha:
#    1009         self.update_alpha(gammat, rho())
#
# File ~\anaconda3\lib\site-packages\gensim\models\ldamodel.py:768, in LdaModel.do_estep(self, chunk, state)
#     766 if state is None:
#     767     state = self.state
# --> 768 gamma, sstats = self.inference(chunk, collect_sstats=True)
#     769 state.sstats += sstats
#     770 state.numdocs += gamma.shape[0]  # avoids calling len(chunk) on a generator
#
# File ~\anaconda3\lib\site-packages\gensim\models\ldamodel.py:733, in LdaModel.inference(self, chunk, collect_sstats)
#     729     assert gammad.dtype == self.dtype
#     730     if collect_sstats:
#     731         # Contribution of document d to the expected sufficient
#     732         # statistics for the M step.
# --> 733         sstats[:, ids] += np.outer(expElogthetad.T, cts / phinorm)
#     735 if len(chunk) > 1:
#     736     logger.debug("%i/%i documents converged within %i iterations", converged, len(chunk), self.iterations)
#
# KeyboardInterrupt:

# %%
#lda model parameters here, could modify these, for now i think 12 is ok
lda_model = LdaModel(corpus=corpus,
                     id2word=dic,
                     num_topics=6,
                     passes=10,
                     alpha='auto',
                     per_word_topics=True)

# %%
#print topics and the words in each
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.018*"look" + 0.013*"airwai" + 0.012*"treat" + 0.012*"mean" + 0.011*"seat" + 0.009*"high" + 0.008*"intern" + 0.008*"guess" + 0.007*"select" + 0.007*"understaf"
# Topic: 1
# Words: 0.030*"number" + 0.030*"email" + 0.016*"tri" + 0.014*"sent" + 0.014*"person" + 0.011*"send" + 0.011*"follow" + 0.011*"hung" + 0.010*"talk" + 0.009*"call"
# Topic: 2
# Words: 0.113*"thank" + 0.075*"tco" + 0.075*"http" + 0.022*"great" + 0.018*"love" + 0.017*"gui" + 0.014*"respons" + 0.014*"appreci" + 0.009*"awesom" + 0.008*"phl"
# Topic: 3
# Words: 0.049*"servic" + 0.046*"custom" + 0.024*"airlin" + 0.020*"ticket" + 0.018*"fly" + 0.016*"like" + 0.013*"travel" + 0.010*"worst" + 0.009*"gui" + 0.009*"experi"
# Topic: 4
# Words: 0.093*"cancel" + 0.051*"flight" + 0.047*"flightl" + 0.034*"tomorrow" + 0.016*"ye" + 0.014*"baggag" + 0.014*"flt" + 0.011*"bag" + 0.011*"rebook" + 0.010*"hang"
# Topic: 5
# Words: 0.087*"flight" + 0.026*"hour" + 0.023*"help" + 0.018*"time" + 0.018*"delai" + 0.017*"wait" + 0.016*"hold" + 0.015*"plane" + 0.013*"need" + 0.012*"amp"

# %%
import pyLDAvis.gensim_models

#create the LDA viz, save it, display it, etc
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dic)
pyLDAvis.save_html(vis, 'lda_topics.html')
pyLDAvis.display(vis)
# Out:
# C:\Users\Julian Sotelo\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1236017616693147048011970051" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el1236017616693147048011970051_data = {"mdsDat": {"x": [-0.29168754054966006, 0.03335025819631229, 0.23674259281307297, -0.1557230958063745, 0.07443904699095327, 0.10287873835569607], "y": [-0.011520376326644148, -0.32879146120628355, 0.009390965997978435, 0.1000488126894938, 0.09811031380021534, 0.13276174504524008], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [43.98700868797945, 19.007262441849036, 11.998870307133854, 11.099129026759568, 8.365511073202832, 5.542218463075259]}, "tinfo": {"Term": ["flight", "thank", "cancel", "http", "tco", "servic", "custom", "flightl", "hour", "tomorrow", "airlin", "delai", "number", "email", "wait", "hold", "time", "great", "ticket", "plane", "seat", "love", "help", "phone", "gui", "look", "call", "gate", "ye", "like", "hour", "wait", "hold", "delai", "plane", "gate", "late", "min", "minut", "sit", "connect", "miss", "let", "flightr", "arriv", "passeng", "updat", "hr", "lax", "get", "pilot", "stuck", "wrong", "answer", "load", "desk", "board", "schedul", "ground", "leav", "time", "try", "onlin", "long", "crew", "help", "agent", "jfk", "flight", "chang", "line", "dai", "reserv", "need", "phone", "amp", "todai", "book", "iv", "got", "weather", "bag", "seat", "airport", "work", "airlin", "custom", "servic", "worst", "experi", "mile", "us", "american", "point", "trip", "differ", "fee", "credit", "horribl", "question", "lack", "charlott", "commun", "believ", "jetblu", "receiv", "poor", "card", "ridicul", "human", "account", "close", "autom", "word", "absolut", "employe", "monei", "disappoint", "ticket", "travel", "tweet", "unit", "pai", "care", "rep", "busi", "like", "fly", "voucher", "year", "bad", "gui", "refund", "week", "that", "rude", "thank", "http", "tco", "great", "appreci", "awesom", "phl", "fleek", "fleet", "hei", "repli", "real", "fault", "tuesdai", "yall", "relat", "record", "safe", "southwest", "quick", "attempt", "sad", "cover", "will", "fun", "rock", "kind", "winter", "weekend", "dmed", "love", "lol", "respons", "locat", "gui", "boston", "good", "amaz", "new", "work", "follow", "team", "flightl", "tomorrow", "cancel", "ye", "dalla", "suppos", "hang", "free", "pick", "claim", "flightlat", "drive", "bring", "idea", "incompet", "deliv", "accommod", "itinerari", "notifi", "rdu", "ewr", "push", "fact", "useless", "even", "fridai", "engin", "matter", "nashvil", "cold", "baggag", "share", "flt", "happi", "snow", "ago", "san", "hotel", "morn", "lost", "flight", "rebook", "reschedul", "bag", "luggag", "right", "dfw", "home", "number", "email", "sent", "person", "hung", "tri", "cater", "miami", "live", "address", "dont", "mia", "month", "entir", "control", "resolv", "support", "plz", "husband", "list", "text", "meal", "wtf", "spend", "forc", "choos", "usual", "altern", "web", "eat", "wifi", "volum", "big", "send", "follow", "nice", "food", "talk", "terribl", "contact", "twice", "speak", "handl", "call", "sai", "twitter", "messag", "phone", "treat", "mean", "high", "guess", "intern", "select", "prioriti", "flyer", "cabin", "understaf", "counter", "sleep", "countri", "offic", "hand", "excus", "access", "prefer", "loung", "unabl", "forward", "fantast", "choic", "cross", "plat", "tsa", "phoenix", "mobil", "fit", "auto", "airwai", "look", "checkin", "seat", "requir", "like", "food"], "Freq": [4739.0, 1458.0, 1116.0, 968.0, 968.0, 995.0, 944.0, 565.0, 1224.0, 408.0, 489.0, 860.0, 266.0, 266.0, 816.0, 771.0, 884.0, 281.0, 424.0, 722.0, 453.0, 245.0, 1162.0, 572.0, 438.0, 247.0, 373.0, 520.0, 186.0, 454.0, 1223.644222553749, 815.5355887945668, 771.1922997393615, 859.3618060426126, 721.8403454357898, 519.356399678249, 433.7548581539542, 342.9077592175547, 340.8460553848605, 275.96191044406726, 267.6002710000925, 366.62617152121567, 284.9908728454339, 182.23394826799174, 163.20771381037608, 247.55132029436106, 169.21603140300886, 354.327903501451, 135.98254226438962, 258.87211915184344, 107.42931920858653, 200.09685923168513, 102.49267499076083, 228.8363989981075,  ...

# %%
##

# %%
#empty topic list to add from using a loop
assigned_topics = []

#assign topics to each row
for doc in corpus:
    doc_topics = lda_model.get_document_topics(doc)
    top_topic = sorted(doc_topics, key=lambda x: x[1], reverse=True)[0]
    assigned_topics.append((top_topic[0], top_topic[1]))

#add the assigned topics and scores to the results_df dataframe
results_df['assigned_topic_id'] = [t[0] for t in assigned_topics]
results_df['assigned_topic_score'] = [t[1] for t in assigned_topics]

# %%
#group results df
grouped_results = results_df.groupby(['airline', 'assigned_topic_id']).size().reset_index(name='count')

#barplot for topics by airline use for loop to create sep graphs for each airline
for airline in results_df['airline'].unique():
    airline_df = grouped_results[grouped_results['airline']==airline]
    plt.figure(figsize=(10,6))
    sns.barplot(x='assigned_topic_id', y='count', data=airline_df)
    plt.title(f"Topic by {airline}")
    plt.xlabel("Topic")
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# ## Part 5: Plot a heat map that shows the sentiment associated with the airlines for different topics.

# %%
#need to create pivot table to use for our heatmap
pivot_table = pd.pivot_table(results_df, values='compound', index='assigned_topic_id', columns='airline', aggfunc=np.mean)

#heatmap
plt.figure(figsize=(14,10))
sns.heatmap(pivot_table, cmap='rocket', annot=True)
plt.title('Sentiment by Topic and Airline')
plt.xlabel('Airline')
plt.ylabel('Topic')
plt.show()
# Out:
# C:\Users\Julian Sotelo\anaconda3\lib\site-packages\seaborn\matrix.py:213: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.cmap = mpl.cm.get_cmap(cmap)

# %%
results_df
# Out:
#           ID         airline    neg    neu    pos  compound  roberta_neg  \
# 0          0  Virgin America  0.000  1.000  0.000    0.0000     0.215634
# 1          1  Virgin America  0.000  1.000  0.000    0.0000     0.497370
# 2          2  Virgin America  0.000  1.000  0.000    0.0000     0.176005
# 3          3  Virgin America  0.343  0.448  0.209   -0.2023     0.556878
# 4          4  Virgin America  0.636  0.364  0.000   -0.5423     0.784228
# ...      ...             ...    ...    ...    ...       ...          ...
# 14635  14635        American  0.000  0.615  0.385    0.3612     0.088788
# 14636  14636        American  0.293  0.707  0.000   -0.7003     0.870435
# 14637  14637        American  0.000  1.000  0.000    0.0000     0.148454
# 14638  14638        American  0.000  0.698  0.302    0.3818     0.154424
# 14639  14639        American  0.000  0.860  0.140    0.0772     0.216572
#
#        roberta_neu  roberta_pos airline_sentiment  \
# 0         0.643773     0.140594           neutral
# 1         0.434796     0.067834          positive
# 2         0.726519     0.097477           neutral
# 3         0.402157     0.040965          negative
# 4         0.187802     0.027970          negative
# ...            ...          ...               ...
# 14635     0.742508     0.168704          positive
# 14636     0.119604     0.009961          negative
# 14637     0.732113     0.119432           neutral
# 14638     0.786269     0.059307          negative
# 14639     0.738961     0.044468           neutral
#
#                                                     text emotion_classif  \
# 0                                                   said        surprise
# 1                plus added commercials experience tacky        surprise
# 2                                   today mean need trip      enthusiasm
# 3        aggressive blast obnoxious entertainment gue...       happiness
# 4                                          big bad thing            hate
# ...                                                  ...             ...
# 14635                 thank got different flight chicago          relief
# 14636    leaving 20 minutes late flight warnings comm...            hate
# 14637                          bring american airlines              hate
# 14638    money change flight answer phones suggestion...         neutral
# 14639    8 ppl need 2 know seats flight plz standby 4...      enthusiasm
#
#                                             cleaned_text  assigned_topic_id  \
# 0                                                 [said]                  5
# 1                     [plu, ad, commerci, experi, tacki]                  3
# 2                              [todai, mean, need, trip]                  5
# 3      [aggress, blast, obnoxi, entertain, guest, fac...                  1
# 4                                      [big, bad, thing]                  5
# ...                                                  ...                ...
# 14635              [thank, got, differ, flight, chicago]                  5
# 14636  [leav, minut, late, flight, warn, commun, minu...                  5
# 14637                          [bring, american, airlin]                  3
# 14638  [monei, chang, flight, answer, phone, suggest,...                  5
# 14639  [ppl, need, know, seat, flight, plz, standbi, ...                  5
#
#        assigned_topic_score
# 0                  0.549607
# 1                  0.320117
# 2                  0.465536
# 3                  0.436059
# 4                  0.366905
# ...                     ...
# 14635              0.530351
# 14636              0.567543
# 14637              0.422319
# 14638              0.724591
# 14639              0.757789
#
# [14640 rows x 15 columns]

# %%
temp_df = results_df.loc[results_df.airline.isin(['American', 'Virgin America'])]

# %%
## part 6

# %%
results_df
# Out:
#           ID         airline    neg    neu    pos  compound  roberta_neg  \
# 0          0  Virgin America  0.000  1.000  0.000    0.0000     0.215634
# 1          1  Virgin America  0.000  1.000  0.000    0.0000     0.497370
# 2          2  Virgin America  0.000  1.000  0.000    0.0000     0.176005
# 3          3  Virgin America  0.343  0.448  0.209   -0.2023     0.556878
# 4          4  Virgin America  0.636  0.364  0.000   -0.5423     0.784228
# ...      ...             ...    ...    ...    ...       ...          ...
# 14635  14635        American  0.000  0.615  0.385    0.3612     0.088788
# 14636  14636        American  0.293  0.707  0.000   -0.7003     0.870435
# 14637  14637        American  0.000  1.000  0.000    0.0000     0.148454
# 14638  14638        American  0.000  0.698  0.302    0.3818     0.154424
# 14639  14639        American  0.000  0.860  0.140    0.0772     0.216572
#
#        roberta_neu  roberta_pos airline_sentiment  \
# 0         0.643773     0.140594           neutral
# 1         0.434796     0.067834          positive
# 2         0.726519     0.097477           neutral
# 3         0.402157     0.040965          negative
# 4         0.187802     0.027970          negative
# ...            ...          ...               ...
# 14635     0.742508     0.168704          positive
# 14636     0.119604     0.009961          negative
# 14637     0.732113     0.119432           neutral
# 14638     0.786269     0.059307          negative
# 14639     0.738961     0.044468           neutral
#
#                                                     text emotion_classif  \
# 0                                                   said        surprise
# 1                plus added commercials experience tacky        surprise
# 2                                   today mean need trip      enthusiasm
# 3        aggressive blast obnoxious entertainment gue...       happiness
# 4                                          big bad thing            hate
# ...                                                  ...             ...
# 14635                 thank got different flight chicago          relief
# 14636    leaving 20 minutes late flight warnings comm...            hate
# 14637                          bring american airlines              hate
# 14638    money change flight answer phones suggestion...         neutral
# 14639    8 ppl need 2 know seats flight plz standby 4...      enthusiasm
#
#                                             cleaned_text  assigned_topic_id  \
# 0                                                 [said]                  5
# 1                     [plu, ad, commerci, experi, tacki]                  3
# 2                              [todai, mean, need, trip]                  5
# 3      [aggress, blast, obnoxi, entertain, guest, fac...                  1
# 4                                      [big, bad, thing]                  5
# ...                                                  ...                ...
# 14635              [thank, got, differ, flight, chicago]                  5
# 14636  [leav, minut, late, flight, warn, commun, minu...                  5
# 14637                          [bring, american, airlin]                  3
# 14638  [monei, chang, flight, answer, phone, suggest,...                  5
# 14639  [ppl, need, know, seat, flight, plz, standbi, ...                  5
#
#        assigned_topic_score
# 0                  0.549607
# 1                  0.320117
# 2                  0.465536
# 3                  0.436059
# 4                  0.366905
# ...                     ...
# 14635              0.530351
# 14636              0.567543
# 14637              0.422319
# 14638              0.724591
# 14639              0.757789
#
# [14640 rows x 15 columns]

# %%
united_df = pd.pivot_table(temp_df.loc[temp_df.airline.isin(['United'])], values = 'compound', index = 'assigned_topic_id', aggfunc='mean')
southwest_df = pd.pivot_table(temp_df.loc[temp_df.airline.isin([''])], values = 'compound', index = 'assigned_topic_id', aggfunc='mean')
pivot_table = pd.concat([southwest_df, united_df], axis=1, keys=['Southwest', 'United'])

# %%
American_df = pd.pivot_table(temp_df.loc[temp_df.airline.isin(['American'])], values = 'compound', index = 'assigned_topic_id', aggfunc='mean')
southwest_df = pd.pivot_table(temp_df.loc[temp_df.airline.isin(['Virgin America'])], values = 'compound', index = 'assigned_topic_id', aggfunc='mean')
pivot_table = pd.concat([southwest_df, American_df], axis=1, keys=['American', 'Virgin America'])
pivot_table
# Out:
#                    American Virgin America
#                    compound       compound
# assigned_topic_id
# 0                  0.152400       0.056213
# 1                  0.312481       0.067390
# 2                  0.365774       0.383387
# 3                  0.263290      -0.002672
# 4                  0.077671      -0.014253
# 5                  0.087099       0.018805

# %%
temp_df = results_df.loc[results_df.airline.isin(['Southwest', 'United'])]

# %%
means_df = temp_df.groupby(['airline', 'emotion_classif', 'assigned_topic_id']).count()['compound'].reset_index()
# SHow viz
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(data=means_df, x='assigned_topic_id', y='compound', hue='emotion_classif', ax=ax)
ax.set_title('Sentiment by Emotion and Airline')
ax.set_xlabel('Emotion')
ax.set_ylabel('Sentiment Score')
plt.show()
# Out:
# C:\Users\Julian Sotelo\anaconda3\lib\site-packages\seaborn\categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# C:\Users\Julian Sotelo\anaconda3\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
temp_df['assigned_topic_id']
# Out:
# 0        5
# 1        3
# 2        5
# 3        1
# 4        5
#         ..
# 14635    5
# 14636    5
# 14637    3
# 14638    5
# 14639    5
# Name: assigned_topic_id, Length: 3263, dtype: int64

# %%
# Create a heat map to visualize the data
sns.heatmap(pivot_table, cmap='RdYlGn', annot=True, fmt='.2f')
plt.title('Sentiment by Topic and Airline')
plt.xlabel('Airline')
plt.ylabel('Topic')
plt.show()
# Out:
# C:\Users\Julian Sotelo\anaconda3\lib\site-packages\seaborn\matrix.py:213: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.cmap = mpl.cm.get_cmap(cmap)

# %%
means_df = temp_df.groupby(['airline', 'emotion_classif']).mean()['compound'].reset_index()
# SHow viz
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(data=means_df, x='emotion_classif', y='compound', hue='airline', ax=ax)
ax.set_title('Sentiment by Emotion and Airline')
ax.set_xlabel('Emotion')
ax.set_ylabel('Sentiment Score')
plt.show()
# Out:
# C:\Users\Julian Sotelo\AppData\Local\Temp\ipykernel_12360\163537792.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   means_df = temp_df.groupby(['airline', 'emotion_classif']).mean()['compound'].reset_index()
# C:\Users\Julian Sotelo\anaconda3\lib\site-packages\seaborn\categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# C:\Users\Julian Sotelo\anaconda3\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %% [markdown]
# ## Part 7: Pick two topics (dimensions) and create a perception map of how all the airlines are located on the two-dimensional map. The axes go from -1 to 1, where 1 denotes that all the tweets pertinent to an airline about that topic are positive, whereas -1 denotes that all tweets are negative

# %%
## Lets Pick topic 8 and topic 7
#topics = results_df.loc[results_df['assigned_topic_id'].isin([7, 8])]

# %%
# Filtering the dataframe
filtered_df = results_df[(results_df['assigned_topic_id'] == 3) | (results_df['assigned_topic_id'] == 4)]

# Compute average compound sentiment score for each airline-topic combination
average_sentiment = filtered_df.groupby(['airline', 'assigned_topic_id'])['compound'].mean().reset_index()

# Normalize sentiment scores to a range of -1 to 1
average_sentiment['normalized_sentiment'] = average_sentiment['compound'].apply(lambda x: max(min(x, 1), -1))

# Pivot the dataframe to have topics as columns
pivoted_df = average_sentiment.pivot_table(index='airline', columns='assigned_topic_id', values='normalized_sentiment').reset_index()

# Plot the perception map
fig, ax = plt.subplots(figsize = (16,14))
pivoted_df.plot.scatter(x=3, y=4, ax=ax, s=100, xlim=(-1, 1), ylim=(-1, 1))

# Label the points with the airline names
for i, row in pivoted_df.iterrows():
    ax.text(row[3], row[4], row['airline'], fontsize=10, horizontalalignment='left', verticalalignment='bottom')

ax.set_xlabel('Topic 4 Sentiment Score')
ax.set_ylabel('Topic 5 Sentiment Score')
ax.set_title('Airline Perception Map for Topics 4 and 5')
ax.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ### Topic 2 - seems to deal with service overall positive
# ### Topic 6 - Seems to deal with credit card miles overall positive
